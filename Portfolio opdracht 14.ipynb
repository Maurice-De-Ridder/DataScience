# %% [markdown]
# ### Portfolio assignment 14
# Perform a bivariate analysis on at least 1 combination of 2 columns with categorical data in the dataset that you chose in portfolio assignment 4.
# - Do you expect their to be a correlation between the two columns?
# - Create a contingency table. Do you observe different ratios between categories here?
# - Create a bar plot for this contingency table. Do you observe different ratios between categories here?
# - Do a chi-squared test. What does the result say? What's the chance of there being a correlation between the two columns?
#
# ![](https://i.imgur.com/0v1CGNV.png)

# %%
import seaborn as sns
import pandas as pd
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt

df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  LifeExpectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
plt.figure(figsize=(16,5)) 
sns.heatmap(df.corr(), annot = True, vmin=-1, vmax=1, center= 0,linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='scatter', x='Schooling', y='Alcohol')
# Out:
# <AxesSubplot:xlabel='Schooling', ylabel='Alcohol'>

# %% [markdown]
# ## Hoe meer geleerd je wordt hoe meer je alchohol consumptie wordt..
# ### Is dit ook gerelateerd aan hoeveelheid incomen?

# %%
df.plot(kind='scatter', x='Income composition of resources', y='Alcohol')
# Out:
# <AxesSubplot:xlabel='Income composition of resources', ylabel='Alcohol'>

# %%
df.plot(kind='scatter', x='GDP', y='Alcohol')
# Out:
# <AxesSubplot:xlabel='GDP', ylabel='Alcohol'>

# %% [markdown]
# ## Het lijkt er niet op dat er een sterke corrolatie is tussen incomen en alchohol gebruik..
# ### Maar wel tussen alcohol en schooling

# %%
contingencyTableSchooling = df.groupby(['Status','Schooling'])['Schooling'].size().unstack('Status',fill_value=0)
chi2_contingency(contingencyTable)
# Out:
# (1339.0083989829614,
#  1.0866925037798293e-179,
#  172,
#  array([[ 4.6818018 , 23.3181982 ],
#         [ 0.16720721,  0.83279279],
#         [ 0.66882883,  3.33117117],
#         [ 0.16720721,  0.83279279],
#         [ 0.16720721,  0.83279279],
#         [ 0.16720721,  0.83279279],
#         [ 0.16720721,  0.83279279],
#         [ 0.50162162,  2.49837838],
#         [ 0.16720721,  0.83279279],
#         [ 0.33441441,  1.66558559],
#         [ 0.33441441,  1.66558559],
#         [ 0.50162162,  2.49837838],
#         [ 0.33441441,  1.66558559],
#         [ 0.16720721,  0.83279279],
#         [ 0.66882883,  3.33117117],
#         [ 0.50162162,  2.49837838],
#         [ 0.66882883,  3.33117117],
#         [ 0.33441441,  1.66558559],
#         [ 0.66882883,  3.33117117],
#         [ 0.33441441,  1.66558559],
#         [ 1.50486486,  7.49513514],
#         [ 1.17045045,  5.82954955],
#         [ 1.00324324,  4.99675676],
#         [ 1.17045045,  5.82954955],
# ...

# %% [markdown]
# ### Er is een duidelijk verband tussen ontwikkelingsstatus en schooling.

# %%
sns.set(rc={'figure.figsize':(45,25)})

contingencyTableSchooling.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Schooling'>

# %% [markdown]
# ### Er is een duidelijk verband tussen ontwikkelingsstatus en schooling.
