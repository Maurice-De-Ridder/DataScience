# %% [markdown]
# ### Portfolio assignment 10
# 15 min: Perform a bivariate analysis (Pearson correlation and scatter plot) on at least 1 combination of 2 columns with numeric data in the dataset that you chose in portfolio assignment 4. Does the correlation and scatter plot match your expectations? Add your answer to your notebook. Commit the Notebook to your portfolio when you're finished.

# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('netflix.csv')
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
dfCorr = df.corr()
dfCorr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\Maurice\AppData\Local\Temp/ipykernel_13804/478106841.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfCorr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_deeb7_row0_col0, #T_deeb7_row1_col1, #T_deeb7_row2_col2, #T_deeb7_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_deeb7_row0_col1, #T_deeb7_row1_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_deeb7_row0_col2, #T_deeb7_row2_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_deeb7_row0_col3, #T_deeb7_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_deeb7_row1_col2, #T_deeb7_row2_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_deeb7_row1_col3, #T_deeb7_row3_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_deeb7_row2_col3, #T_deeb7_row3_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_deeb7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ratingDescription</th>
#       <th class="col_heading level0 col1" >release year</th>
#       <th class="col_heading level0 col2" >user rating score</th>
#       <th class="col_heading level0 col3" >user rating size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_deeb7_level0_row0" class="row_heading level0 row0" >ratingDescription</th>
#       <td id="T_deeb7_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_deeb7_row0_col1" class="data row0 col1" >0.41</td>
#       <td id="T_deeb7_row0_col2" class="data row0 col2" >0.32</td>
#       <td id="T_deeb7_row0_col3" class="data row0 col3" >-0.23</td>
#     </tr>
#     <tr>
#       <th id="T_deeb7_level0_row1" class="row_heading level0 row1" >release year</th>
#       <td id="T_deeb7_row1_col0" class="data row1 col0" >0.41</td>
#       <td id="T_deeb7_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_deeb7_row1_col2" class="data row1 col2" >0.27</td>
#       <td id="T_deeb7_row1_col3" class="data row1 col3" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_deeb7_level0_row2" class="row_heading level0 row2" >user rating score</th>
#       <td id="T_deeb7_row2_col0" class="data row2 col0" >0.32</td>
#       <td id="T_deeb7_row2_col1" class="data row2 col1" >0.27</td>
#       <td id="T_deeb7_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_deeb7_row2_col3" class="data row2 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_deeb7_level0_row3" class="row_heading level0 row3" >user rating size</th>
#       <td id="T_deeb7_row3_col0" class="data row3 col0" >-0.23</td>
#       <td id="T_deeb7_row3_col1" class="data row3 col1" >-0.00</td>
#       <td id="T_deeb7_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_deeb7_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.plot(figsize=(15,8), x='release year', y='user rating score')
# Out:
# <AxesSubplot:xlabel='release year'>

# %% [markdown]
# ## Mmhm..
