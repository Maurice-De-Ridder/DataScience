# %% [markdown]
# ### Portfolio assignment 10
# 15 min: Perform a bivariate analysis (Pearson correlation and scatter plot) on at least 1 combination of 2 columns with numeric data in the dataset that you chose in portfolio assignment 4. Does the correlation and scatter plot match your expectations? Add your answer to your notebook. Commit the Notebook to your portfolio when you're finished.

# %%
import seaborn as sns
import pandas as pd
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt

df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  LifeExpectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
dfCorr = df.corr()
dfCorr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\Maurice\AppData\Local\Temp/ipykernel_66668/478106841.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfCorr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_b8cbc_row0_col0, #T_b8cbc_row1_col1, #T_b8cbc_row2_col2, #T_b8cbc_row3_col3, #T_b8cbc_row3_col9, #T_b8cbc_row4_col4, #T_b8cbc_row5_col5, #T_b8cbc_row6_col6, #T_b8cbc_row7_col7, #T_b8cbc_row8_col8, #T_b8cbc_row9_col3, #T_b8cbc_row9_col9, #T_b8cbc_row10_col10, #T_b8cbc_row11_col11, #T_b8cbc_row12_col12, #T_b8cbc_row13_col13, #T_b8cbc_row14_col14, #T_b8cbc_row15_col15, #T_b8cbc_row16_col16, #T_b8cbc_row17_col17, #T_b8cbc_row18_col18, #T_b8cbc_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b8cbc_row0_col1, #T_b8cbc_row1_col0, #T_b8cbc_row11_col18, #T_b8cbc_row18_col11 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### Lets analyse alcohol consumption...

# %%
df.plot(kind='scatter', x='Schooling', y='Alcohol')
# Out:
# <AxesSubplot:xlabel='Schooling', ylabel='Alcohol'>

# %%
df.plot(kind='scatter', x='Income composition of resources', y='Alcohol')
# Out:
# <AxesSubplot:xlabel='Income composition of resources', ylabel='Alcohol'>

# %% [markdown]
# ### It seems that schooling and income are both linked to alcohol consumption, but only slightly.
# #### I did not expect there to be such a corrolation between alcohol and schooling.
